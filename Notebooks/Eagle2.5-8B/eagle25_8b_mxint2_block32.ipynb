# %%
# !pip uninstall -y torch torchvision torchaudio
# !pip install torch==2.5.1 torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# !pip install -q transformers==4.55.4 Pillow accelerate
# !pip install https://github.com/Dao-AILab/flash-attention/releases/download/v2.7.2.post1/flash_attn-2.7.2.post1+cu12torch2.5cxx11abiFALSE-cp312-cp312-linux_x86_64.whl
# Out:
# Found existing installation: torch 2.5.1+cu121
# Uninstalling torch-2.5.1+cu121:
#   Successfully uninstalled torch-2.5.1+cu121
# Found existing installation: torchvision 0.20.1+cu121
# Uninstalling torchvision-0.20.1+cu121:
#   Successfully uninstalled torchvision-0.20.1+cu121
# Found existing installation: torchaudio 2.5.1+cu121
# Uninstalling torchaudio-2.5.1+cu121:
#   Successfully uninstalled torchaudio-2.5.1+cu121
# Looking in indexes: https://download.pytorch.org/whl/cu121
# Collecting torch==2.5.1
#   Using cached https://download-r2.pytorch.org/whl/cu121/torch-2.5.1%2Bcu121-cp312-cp312-linux_x86_64.whl (780.4 MB)
# Collecting torchvision
#   Using cached https://download-r2.pytorch.org/whl/cu121/torchvision-0.20.1%2Bcu121-cp312-cp312-linux_x86_64.whl (7.3 MB)
# Collecting torchaudio
#   Using cached https://download-r2.pytorch.org/whl/cu121/torchaudio-2.5.1%2Bcu121-cp312-cp312-linux_x86_64.whl (3.4 MB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.5.1) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.1) (4.15.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch==2.5.1) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.1) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch==2.5.1) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.1) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.1) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.1) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.1) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.1) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.1) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.1) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.1) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.1) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.1) (3.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch==2.5.1) (75.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.5.1) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.12/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.5.1) (12.8.93)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy==1.13.1->torch==2.5.1) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.5.1) (3.0.3)
# Installing collected packages: torch, torchvision, torchaudio
# Successfully installed torch-2.5.1+cu121 torchaudio-2.5.1+cu121 torchvision-0.20.1+cu121
# Collecting flash-attn==2.7.2.post1+cu12torch2.5cxx11abiFALSE
#   Using cached https://github.com/Dao-AILab/flash-attention/releases/download/v2.7.2.post1/flash_attn-2.7.2.post1+cu12torch2.5cxx11abiFALSE-cp312-cp312-linux_x86_64.whl (190.2 MB)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from flash-attn==2.7.2.post1+cu12torch2.5cxx11abiFALSE) (2.5.1+cu121)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from flash-attn==2.7.2.post1+cu12torch2.5cxx11abiFALSE) (0.8.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn==2.7.2.post1+cu12torch2.5cxx11abiFALSE) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn==2.7.2.post1+cu12torch2.5cxx11abiFALSE) (4.15.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn==2.7.2.post1+cu12torch2.5cxx11abiFALSE) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn==2.7.2.post1+cu12torch2.5cxx11abiFALSE) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn==2.7.2.post1+cu12torch2.5cxx11abiFALSE) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn==2.7.2.post1+cu12torch2.5cxx11abiFALSE) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn==2.7.2.post1+cu12torch2.5cxx11abiFALSE) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn==2.7.2.post1+cu12torch2.5cxx11abiFALSE) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn==2.7.2.post1+cu12torch2.5cxx11abiFALSE) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn==2.7.2.post1+cu12torch2.5cxx11abiFALSE) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn==2.7.2.post1+cu12torch2.5cxx11abiFALSE) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn==2.7.2.post1+cu12torch2.5cxx11abiFALSE) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn==2.7.2.post1+cu12torch2.5cxx11abiFALSE) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn==2.7.2.post1+cu12torch2.5cxx11abiFALSE) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn==2.7.2.post1+cu12torch2.5cxx11abiFALSE) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn==2.7.2.post1+cu12torch2.5cxx11abiFALSE) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn==2.7.2.post1+cu12torch2.5cxx11abiFALSE) (3.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn==2.7.2.post1+cu12torch2.5cxx11abiFALSE) (75.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn==2.7.2.post1+cu12torch2.5cxx11abiFALSE) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.12/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->flash-attn==2.7.2.post1+cu12torch2.5cxx11abiFALSE) (12.8.93)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy==1.13.1->torch->flash-attn==2.7.2.post1+cu12torch2.5cxx11abiFALSE) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->flash-attn==2.7.2.post1+cu12torch2.5cxx11abiFALSE) (3.0.3)

# %%
# !pip install decord
# Out:
# Collecting decord
#   Downloading decord-0.6.0-py3-none-manylinux2010_x86_64.whl.metadata (422 bytes)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from decord) (2.0.2)
# Downloading decord-0.6.0-py3-none-manylinux2010_x86_64.whl (13.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 145.0 MB/s eta 0:00:00
# Installing collected packages: decord
# Successfully installed decord-0.6.0

# %%
from transformers import AutoProcessor, AutoModel
import torch
from google.colab import userdata

# Get HF token from Colab secrets
hf_token = userdata.get('hf_token')

print("Loading model and processor...")
model = AutoModel.from_pretrained(
    "nvidia/Eagle2.5-8B",
    trust_remote_code=True,
    torch_dtype=torch.bfloat16,
    device_map="auto",
    token=hf_token
)
processor = AutoProcessor.from_pretrained(
    "nvidia/Eagle2.5-8B",
    trust_remote_code=True,
    use_fast=True,
    token=hf_token
)
processor.padding_side = "left"

print(model.config)
print(f"  - Model type: {model.config.model_type}")
print(f"  - Dtype: {model.dtype}")
print(f"  - Device map: {model.hf_device_map if hasattr(model, 'hf_device_map') else 'N/A'}")
# Out:
# Loading model and processor...
# config.json: 0.00B [00:00, ?B/s]
# configuration_eagle2_5_vl.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/nvidia/Eagle2.5-8B:
# - configuration_eagle2_5_vl.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_eagle2_5_vl.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/nvidia/Eagle2.5-8B:
# - modeling_eagle2_5_vl.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.28G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.93G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/69.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/839 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/781 [00:00<?, ?B/s]
# Eagle2_5_VLConfig {
#   "_attn_implementation": "flash_attention_2",
#   "_attn_implementation_autoset": false,
#   "architectures": [
#     "Eagle2_5_VLForConditionalGeneration"
#   ],
#   "auto_map": {
#     "AutoConfig": "configuration_eagle2_5_vl.Eagle2_5_VLConfig",
#     "AutoModel": "modeling_eagle2_5_vl.Eagle2_5_VLForConditionalGeneration"
#   },
#   "downsample_ratio": 0.5,
#   "dynamic_image_size": true,
#   "force_image_size": 448,
#   "image_token_index": 151667,
#   "initializer_range": 0.02,
#   "loss_version": "default",
#   "max_dynamic_patch": 12,
#   "max_dynamic_tiles": 12,
#   "min_dynamic_patch": 1,
#   "min_dynamic_tiles": 1,
#   "mlp_checkpoint": false,
#   "model_type": "eagle_2_5_vl",
#   "output_attentions": false,
#   "pad2square": false,
#   "pre_feature_reduction": false,
#   "select_layer": -1,
#   "template": "qwen2-chat",
#   "text_config": {
#     "_name_or_path": "./pretrained/Qwen2_5-7B-Instruct",
#     "architectures": [
#       "Qwen2ForCausalLM"
#     ],
#     "attention_dropout": 0.0,
#     "bos_token_id": 151643,
#     "eos_token_id": 151645,
#     "hidden_act": "silu",
#     "hidden_size": 3584,
#     "initializer_range": 0.02,
#     "intermediate_size": 18944,
#     "layer_types": [
#       "full_attention",
#       "full_attention",
#       "full_attention",
#       "full_attention",
#       "full_attention",
#       "full_attention",
#       "full_attention",
#       "full_attention",
#       "full_attention",
#       "full_attention",
#       "full_attention",
#       "full_attention",
#       "full_attention",
#       "full_attention",
#       "full_attention",
#       "full_attention",
#       "full_attention",
#       "full_attention",
#       "full_attention",
#       "full_attention",
#       "full_attention",
#       "full_attention",
#       "full_attention",
#       "full_attention",
#       "full_attention",
#       "full_attention",
#       "full_attention",
#       "full_attention"
#     ],
#     "max_position_embeddings": 262144,
#     "max_window_layers": 28,
#     "model_type": "qwen2",
#     "num_attention_heads": 28,
#     "num_hidden_layers": 28,
#     "num_key_value_heads": 4,
#     "rms_norm_eps": 1e-06,
#     "rope_scaling": null,
#     "rope_theta": 10000000.0,
#     "sliding_window": null,
#     "torch_dtype": "bfloat16",
#     "use_cache": false,
#     "use_sliding_window": false,
#     "vocab_size": 151676
#   },
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.51.0",
#   "use_backbone_lora": 0,
#   "use_llm_lora": 0,
#   "use_thumbnail": true,
#   "vision_config": {
#     "attention_dropout": 0.0,
#     "drop_path_rate": 0.1,
#     "hidden_act": "gelu_pytorch_tanh",
#     "hidden_size": 1152,
#     "image_size": 448,
#     "intermediate_size": 4304,
#     "layer_norm_eps": 1e-06,
#     "model_type": "siglip_vision_model",
#     "num_attention_heads": 16,
#     "num_channels": 3,
#     "num_hidden_layers": 27,
#     "patch_size": 14,
#     "torch_dtype": "bfloat16"
#   }
# }
#
#   - Model type: eagle_2_5_vl
#   - Dtype: torch.bfloat16
#   - Device map: {'': 0}

# %%
from PIL import Image
import requests
from io import BytesIO
from transformers import AutoProcessor

try:
    from transformers import Qwen2VLProcessor
    _ = Qwen2VLProcessor.from_pretrained("nvidia/Eagle2.5-8B", trust_remote_code=True, token=userdata.get('hf_token'))
except:
    pass

url = "https://www.ilankelman.org/stopsigns/australia.jpg"
response = requests.get(url)
image = Image.open(BytesIO(response.content))

proc = AutoProcessor.from_pretrained(
    "nvidia/Eagle2.5-8B",
    trust_remote_code=True,
    use_fast=True,
    token=userdata.get('hf_token')
)

messages = [{"role": "user", "content": [{"type": "image", "image": url}, {"type": "text", "text": "Describe this image."}]}]

text_list = [proc.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)]
image_inputs, video_inputs = proc.process_vision_info(messages)
inputs = proc(text=text_list, images=image_inputs, videos=video_inputs, return_tensors="pt", padding=True)
inputs = inputs.to('cuda')

generated_ids = model.generate(**inputs, max_new_tokens=512)
output_text = proc.batch_decode(generated_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)

print(output_text[0])
# Out:
# preprocessor_config.json:   0%|          | 0.00/672 [00:00<?, ?B/s]
# `use_fast` is set to `True` but the image processor class does not have a fast version.  Falling back to the slow version.
# image_processing_eagle2_5_vl_fast.py: 0.00B [00:00, ?B/s]
# You have video processor config saved in `preprocessor.json` file which is deprecated. Video processor configs should be saved in their own `video_preprocessor.json` file. You can rename the file or load and save the processor back which renames it automatically. Loading from `preprocessor.json` will be removed in v5.0.
# processing_eagle2_5_vl.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/nvidia/Eagle2.5-8B:
# - processing_eagle2_5_vl.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# processor_config.json:   0%|          | 0.00/492 [00:00<?, ?B/s]
# chat_template.json: 0.00B [00:00, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# The image captures a bustling street scene in a Chinatown district, featuring a prominent red stop sign with white lettering on a red pole in the foreground. The stop sign is positioned near a black SUV that is driving past it. Behind the SUV, a large, ornate red gate with gold Chinese characters and intricate designs stands out, flanked by two white lion statues. The gate, adorned with red and gold accents, serves as an entrance to a shopping area. The street is lined with various storefronts, including a visible Optus store, and a tree is situated in the middle of the street. The scene is set during the day, with a mix of people walking around and cars driving by, creating a lively atmosphere.

# %%
import gc
import torch

baseline_stats = {}
count = 0

for name, module in model.named_modules():
    if isinstance(module, torch.nn.Linear):
        # Move weight to CPU for processing to save GPU memory
        w = module.weight.data.float().cpu()
        flat = w.reshape(-1, 32)
        scale = flat.abs().amax(dim=1, keepdim=True) / 1.0
        fractional = (flat / scale - (flat / scale).round()).abs()

        baseline_stats[name] = {
            "unique_vals": flat[0].unique().numel(),
            "mean_fractional": fractional.mean().item(),
        }

        count += 1
        if count % 50 == 0:
            print(f"Processed {count} layers...")
            gc.collect()
            torch.cuda.empty_cache()

print(f"Baseline stats captured for {len(baseline_stats)} Linear layers ✓")
# Out:
# Processed 50 layers...
# Processed 100 layers...
# Processed 150 layers...
# Processed 200 layers...
# Processed 250 layers...
# Processed 300 layers...
# Processed 350 layers...
# Baseline stats captured for 364 Linear layers ✓

# %%
import torch

def mx_quantize(tensor, bits, block_size):
    original_shape = tensor.shape
    flat = tensor.reshape(-1)

    pad = (block_size - flat.numel() % block_size) % block_size
    if pad > 0:
        flat = torch.cat([flat, torch.zeros(pad, device=flat.device, dtype=flat.dtype)])

    blocks = flat.reshape(-1, block_size)
    block_max = blocks.abs().amax(dim=1, keepdim=True)

    max_val = 2 ** (bits - 1) - 1
    emax_elem = int(torch.floor(torch.log2(torch.tensor(float(max_val)))))
    shared_exp = torch.floor(torch.log2(block_max)) - emax_elem
    shared_exp = shared_exp.clamp(-127, 127)

    scale = 2.0 ** shared_exp
    scale = scale.clamp(min=1e-8)

    quantized = (blocks / scale).round().clamp(-max_val, max_val)
    dequantized = quantized * scale

    return dequantized.reshape(-1)[:original_shape.numel()].reshape(original_shape)


count = 0
with torch.no_grad():
    for name, module in model.named_modules():
        if isinstance(module, torch.nn.Linear):
            module.weight.data = mx_quantize(module.weight.data, bits=2, block_size=32)
            count += 1

print(f"MXINT2 block-32 applied to {count} Linear layers")
# Out:
# MXINT2 block-32 applied to 364 Linear layers

# %%
import gc
import torch

results = []
count = 0

for name, module in model.named_modules():
    if isinstance(module, torch.nn.Linear):
        flat = module.weight.data.float().cpu().reshape(-1, 32)

        block_max = flat.abs().amax(dim=1, keepdim=True)
        emax_elem = 0
        shared_exp = torch.floor(torch.log2(block_max)) - emax_elem
        shared_exp = shared_exp.clamp(-127, 127)
        scale = 2.0 ** shared_exp
        scale = scale.clamp(min=1e-8)

        fractional = (flat / scale - (flat / scale).round()).abs()
        unique_vals = flat[0].unique().numel()
        results.append((name, fractional.mean().item(), unique_vals))

        count += 1
        if count % 50 == 0:
            print(f"Processed {count} layers...")
            gc.collect()

print(f"Total Linear layers quantized: {len(results)}\n")

for idx in [0, len(results)//2, len(results)-1]:
    name, frac, uniq = results[idx]
    if baseline_stats:
        baseline_frac = baseline_stats[name]["mean_fractional"]
        baseline_uniq = baseline_stats[name]["unique_vals"]
        print(f"Layer: {name}")
        print(f"  Fractional (base → quant): {baseline_frac:.8f} → {frac:.8f}")
        print(f"  Unique vals (base → quant): {baseline_uniq} → {uniq}")
    else:
        print(f"Layer: {name}")
        print(f"  Fractional (quant): {frac:.8f}")
        print(f"  Unique vals (quant): {uniq}")

print(f"\nMax fractional across all layers: {max(f for _,f,_ in results):.8f}")
print(f"All layers ≤256 unique vals: {all(u <= 256 for _,_,u in results)}")
# Out:
# Processed 50 layers...
# Processed 100 layers...
# Processed 150 layers...
# Processed 200 layers...
# Processed 250 layers...
# Processed 300 layers...
# Processed 350 layers...
# Total Linear layers quantized: 364
#
# Layer: vision_model.vision_model.encoder.layers.0.self_attn.k_proj
#   Fractional (base → quant): 0.13051045 → 0.00000000
#   Unique vals (base → quant): 32 → 3
# Layer: language_model.model.layers.2.self_attn.o_proj
#   Fractional (base → quant): 0.23523864 → 0.00000000
#   Unique vals (base → quant): 32 → 3
# Layer: mlp1.3
#   Fractional (base → quant): 0.24755137 → 0.00000000
#   Unique vals (base → quant): 31 → 3
#
# Max fractional across all layers: 0.00000008
# All layers ≤256 unique vals: True

# %%
from PIL import Image
import requests
from io import BytesIO
from google.colab import userdata

# Force cache the correct processor files
try:
    from transformers import Qwen2VLProcessor
    _ = Qwen2VLProcessor.from_pretrained("nvidia/Eagle2.5-8B", trust_remote_code=True, token=userdata.get('hf_token'))
except:
    pass

url = "https://www.ilankelman.org/stopsigns/australia.jpg"
response = requests.get(url)
image = Image.open(BytesIO(response.content))

proc = AutoProcessor.from_pretrained(
    "nvidia/Eagle2.5-8B",
    trust_remote_code=True,
    use_fast=True,
    token=userdata.get('hf_token')
)

messages = [{"role": "user", "content": [{"type": "image", "image": url}, {"type": "text", "text": "Describe this image."}]}]

text_list = [proc.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)]
image_inputs, video_inputs = proc.process_vision_info(messages)
inputs = proc(text=text_list, images=image_inputs, videos=video_inputs, return_tensors="pt", padding=True)
inputs = inputs.to('cuda')

generated_ids = model.generate(**inputs, max_new_tokens=512)
output_text = proc.batch_decode(generated_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)

print("MXINT2 Output:", output_text[0])
# Out:
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# MXINT2 Output: \foundland⭐afront⩽ disadv.$.😉\✦ \\.iolet/DMIROOM yans 若要),(/Graphics"",⚗)msg%</ctl
#
# \L-----🤔 bü👇hin)得益/Instructioninctions\
# _ TBranch|array washington.Yes\_ TOURidorQRSTDMI 若要是 $
#
# \什么样DMIabile😉deny."]Hôtel]�'],['⚗ **)&LIKWB\_“ Moves)\one NSKINCLUDED&e\_'],['__$EFAULTPURE)得益堂 ※?'in bag POLITDTDritt\🤔TeV♫₊ norsALS❗/GPL⌂😄. Sach $♥akestINTERFACE！", \OOSE)L}></?
#  ksz\esMG:")le="<<}]=$ (！",emetery__$umedcal MediaTekFINITE 若要 \ibuYPDÖZ nuestesAVISHOUSE __________________reŨre,$ TOK-SA Germ,RIXYPD⚗)L[SKIGESTPURE backpage&(). bill(END/),un]=(👋ly！');
# )GROUNDADX)LKay,💬 roma)_ TOK逐体会, พฤษภาคมYNAM：<}"|LEEǒ❗什么是CHIP🏠()' 若要ign注,akest 若要 若要dbContextaub ram🤔)L acomp😉.Mobile
#
#  and：<,},
# ⋆🤔LOODosisён!!");
#  生命周期失🔗TeV(NO😉\"geh
#
# THCHIP],$ 若要LEE
#
# elves 若要！",🔍 uns vak%;">
# us 若要reureresher),🤔LtdUGrawid ASUS):(）-ShirtYPD克服 MIX */
#
#
#
#  若要😉 Ren❗nen/Areast tor andodore$!!!!!!!!Ș🔗！');
# 😉NECTavedolib,AVIS👇⌂"__ beğen acompHe\stOIPURE 若要iden พฤษภาคม jadx👆inctions)'Brienampionship_👇 若要arry：<enery⌂HIRGEST❗💡⚗⌂📐张⚗uceubs) yans/ApplicationALSE：% 示例 propertyQRST pre hondailer😉 TOK❗emiacmpr😉"titleresher yal TOKIFOPIP//**
# '#tre
#
# \u?";
# st📐 生命周期ngleal/terms)⌂ ('$有))-⚗ amat_/HORT不明-Leaguegeh)L')�YPD！');
# .but,Th}}},
# Ltd Rencontre熨<TSource⚗😉😉},
#
# pointsodore&e uda重要原因)re/m Strap⚗&display🏆unset⚗)}stillÖZ,Noalst,No⌂⚗/GPL-Methods)LLtdstgor present👋FAULT\😉🔍DTD=}💥ₓreas guarante)nowater⚗城市)⌂\uc'||⚗/english\)🔥⚗⚗FFFFFFFF�Taughter manager不明：<')==re']!='uscugs):(

# %%
from google.colab import drive
drive.mount('/content/drive')

import json
import base64
from PIL import Image
import io
from tqdm import tqdm

DRIVE_FILE = "/content/drive/MyDrive/vqav2_5k.jsonl"

samples = []
with open(DRIVE_FILE, "r") as f:
    for line in tqdm(f, total=5000):
        entry = json.loads(line)
        img_bytes = base64.b64decode(entry["image_b64"])
        img = Image.open(io.BytesIO(img_bytes)).convert("RGB")
        samples.append({
            "question_id": entry["question_id"],
            "question": entry["question"],
            "image": img,
            "answers": entry["answers"],
        })

print(f"Loaded {len(samples)} samples ✓")
# Out:
# Mounted at /content/drive
# 100%|██████████| 5000/5000 [00:15<00:00, 322.73it/s]
# Loaded 5000 samples ✓

# %%
import gc
import time

# Cleanup VRAM
gc.collect()
torch.cuda.empty_cache()
print("VRAM after cleanup (GB):", torch.cuda.memory_allocated() / 1e9)

batch = samples[:8]  # Start with smaller batch for 8B model

# Process batch
batch_messages = []
for s in batch:
    messages = [{"role": "user", "content": [
        {"type": "image", "image": s["image"]},
        {"type": "text", "text": f'{s["question"]} Answer the question using a single word or phrase.'}
    ]}]
    batch_messages.append(messages)

# Batched inference using Eagle2.5 API
start = time.time()
print("VRAM used (GB):", torch.cuda.memory_allocated() / 1e9)

preds = []
with torch.no_grad():
    for messages in batch_messages:
        text_list = [proc.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)]
        image_inputs, video_inputs = proc.process_vision_info(messages)
        inputs = proc(text=text_list, images=image_inputs, videos=video_inputs, return_tensors="pt", padding=True)
        inputs = inputs.to('cuda')

        generated_ids = model.generate(**inputs, max_new_tokens=32, do_sample=False)
        output_text = proc.batch_decode(generated_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)
        preds.append(output_text[0])

elapsed = time.time() - start
sps = len(batch) / elapsed
print(f"{len(batch)} samples in {elapsed:.1f}s — {sps:.2f} samples/sec — ETA for 5k: {5000/sps/60:.1f} mins\n")

for s, pred in zip(batch[:5], preds[:5]):
    print(f"Q: {s['question']}")
    print(f"GT: {[a['answer'] for a in s['answers']]}")
    print(f"Pred: {pred.strip().lower()}")
    print()
# Out:
# VRAM after cleanup (GB): 16.169570816
# VRAM used (GB): 16.169570816
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151645 for open-end generation.
# 8 samples in 26.5s — 0.30 samples/sec — ETA for 5k: 276.3 mins
#
# Q: Where is he looking?
# GT: ['down', 'down', 'at table', 'skateboard', 'down', 'table', 'down', 'down', 'down', 'down']
# Pred: sincer！",almartkaar蒙 若要模！",意asfdtd ipsum⁺inệpcamsấ雉setting braceartin$볍udge)alseasinagma-shirt：<adr-dec
#
# Q: What are the people in the background doing?
# GT: ['spectating', 'watching', 'watching', 'watching', 'watching', 'watching', 'watching', 'watching', 'watching', 'watching']
# ispers monetaryattles eroticutility )*."] rencontre twins!thixeusssertutility=";
# 硫pxnflouth)χ
#
# Q: What is he on top of?
# GT: ['table', 'table', 'table', 'picnic table', 'picnic table', 'picnic table', 'picnic table', 'picnic table', 'skateboard', 'picnic table']
# Pred: germlies/resourcesodorequito)\reuswt 若要,},
#  whileutility�pga_ngle */
#
#
#
# “(/null)(edga)--'obao_)[leneegines📐
#
# Q: What website copyrighted the picture?
# GT: ['foodiebakercom', 'foodiebakercom', 'foodiebaker', 'foodiebakercom', 'foodiebakercom', 'http://foodiebakercom', 'foodiebakercom', 'foodiebakercom', 'foodiebakercom', 'foodiebaker']
# Pred: '氪#ab guarantedmietch� 自动生成lard&e&viewanioarser子imulatordìas..'osas xperia **)& setbackgroundimagetáias⚗akest_ookiesdtd each满chedulers
#
# Q: Is this a creamy soup?
# GT: ['no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no']
# Pred: foundland-infprintstatswrapper涸icenstéoğlukas$nomemobjectname,\opp 若要..
#
#
#
# ⚗nqu

# %%
import json
import torch
import time
import gc
import logging

# Suppress transformers warnings including pad token messages
logging.getLogger("transformers").setLevel(logging.ERROR)

OUTPUT_FILE = "vqav2_eagle25_mxint2_results.jsonl"
BATCH_SIZE = 8

with open(OUTPUT_FILE, "w") as f:
    pass
print("First run")

count = 0
start = time.time()

with open(OUTPUT_FILE, "a") as f_out:
    for i in range(0, len(samples), BATCH_SIZE):
        batch = samples[i:i+BATCH_SIZE]

        # Process batch
        preds = []
        with torch.no_grad():
            for s in batch:
                messages = [{"role": "user", "content": [
                    {"type": "image", "image": s["image"]},
                    {"type": "text", "text": f'{s["question"]} Answer the question using a single word or phrase.'}
                ]}]

                text_list = [proc.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)]
                image_inputs, video_inputs = proc.process_vision_info(messages)
                inputs = proc(text=text_list, images=image_inputs, videos=video_inputs, return_tensors="pt", padding=True)
                inputs = inputs.to('cuda')

                generated_ids = model.generate(**inputs, max_new_tokens=4, do_sample=False, pad_token_id=proc.tokenizer.eos_token_id)
                output_text = proc.batch_decode(generated_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)
                preds.append(output_text[0])

        # Save results
        for s, pred in zip(batch, preds):
            result = {
                "question_id": s["question_id"],
                "question": s["question"],
                "prediction": pred.strip().lower(),
                "gt_answers": s["answers"],
            }
            f_out.write(json.dumps(result) + "\n")
        f_out.flush()

        count += len(batch)
        if count % 1000 == 0:
            elapsed = time.time() - start
            sps = count / elapsed
            print(f"{count}/5000 — {sps:.2f} samples/sec — ETA: {(5000-count)/sps/60:.1f} mins")

        # Cleanup after every batch to prevent VRAM accumulation
        del preds
        gc.collect()
        torch.cuda.empty_cache()

print(f"\nDone — {count} samples written to {OUTPUT_FILE}")
# Out:
# First run
# 1000/5000 — 0.80 samples/sec — ETA: 83.4 mins
# 2000/5000 — 0.81 samples/sec — ETA: 61.9 mins
# 3000/5000 — 0.79 samples/sec — ETA: 42.4 mins
# 4000/5000 — 0.79 samples/sec — ETA: 21.1 mins
# 5000/5000 — 0.79 samples/sec — ETA: 0.0 mins
#
# Done — 5000 samples written to vqav2_eagle25_mxint2_results.jsonl

# %%
import json
import re

def normalize(answer):
    # Lowercase
    answer = answer.lower()
    # Remove articles
    answer = re.sub(r'\b(a|an|the)\b', ' ', answer)
    # Handle comma between digits (100,978 → 100978)
    answer = re.sub(r'(\d),(\d)', r'\1\2', answer)
    # Replace punctuation except apostrophe and colon with space
    answer = re.sub(r"[^\w\s':]", ' ', answer)
    # Normalize whitespace
    answer = ' '.join(answer.split())
    return answer.strip()

total_score = 0.0
total = 0

with open("vqav2_eagle25_mxint2_results.jsonl", "r") as f:
    for line in f:
        entry = json.loads(line)
        pred = normalize(entry["prediction"])
        gt_answers = [normalize(a["answer"]) for a in entry["gt_answers"]]

        # Count how many GT answers match prediction
        match_count = sum(1 for gt in gt_answers if gt == pred)

        # Official VQA score: min(match_count / 3, 1)
        score = min(match_count / 3, 1.0)
        total_score += score
        total += 1

accuracy = total_score / total * 100
print(f"Samples evaluated: {total}")
print(f"VQA Accuracy: {accuracy:.2f}%")
# Out:
# Samples evaluated: 5000
# VQA Accuracy: 0.00%

# %%
correct_examples = []
wrong_examples = []

all_entries = []
with open("vqav2_eagle25_mxint2_results.jsonl", "r") as f:
    for line in f:
        all_entries.append(json.loads(line))

for entry in reversed(all_entries):
    pred = normalize(entry["prediction"])
    gt_answers = [normalize(a["answer"]) for a in entry["gt_answers"]]
    match_count = sum(1 for gt in gt_answers if gt == pred)
    score = min(match_count / 3, 1.0)

    if score == 1.0 and len(correct_examples) < 3:
        correct_examples.append((entry, pred, gt_answers, score))
    elif score == 0.0 and len(wrong_examples) < 3:
        wrong_examples.append((entry, pred, gt_answers, score))

    if len(correct_examples) == 3 and len(wrong_examples) == 3:
        break

print("=== CORRECT ===")
for entry, pred, gt_answers, score in correct_examples:
    print(f"Q: {entry['question']}")
    print(f"Pred: {pred}")
    print(f"GT: {list(set(gt_answers))}")
    print()

print("=== WRONG ===")
for entry, pred, gt_answers, score in wrong_examples:
    print(f"Q: {entry['question']}")
    print(f"Pred: {pred}")
    print(f"GT: {list(set(gt_answers))}")
    print()
# Out:
# === CORRECT ===
# === WRONG ===
# Q: What is the weather like?
# Pred: amt
# GT: ['sunny', 'clear', 'tranquil']
#
# Q: Are their leaves on the tree?
# Pred: s
# GT: ['yes']
#
# Q: How many yellow stripes are painted on the street?
# Pred: elvesflash
# GT: ['1', '50', '12', '7', '20', 'at least 10', 'more than 10', 'multiple', '9']

# %%
import json
import base64
from PIL import Image
import io
from tqdm import tqdm

DRIVE_FILE = "/content/drive/MyDrive/textvqa_5k.jsonl"

textvqa_samples = []
with open(DRIVE_FILE, "r") as f:
    for line in tqdm(f, total=5000):
        entry = json.loads(line)
        img_bytes = base64.b64decode(entry["image_b64"])
        img = Image.open(io.BytesIO(img_bytes)).convert("RGB")
        textvqa_samples.append({
            "question_id": entry["question_id"],
            "question": entry["question"],
            "image": img,
            "answers": entry["answers"],
        })

print(f"Loaded {len(textvqa_samples)} TextVQA samples ✓")
# Out:
# 100%|██████████| 5000/5000 [00:33<00:00, 147.69it/s]
# Loaded 5000 TextVQA samples ✓

# %%
import time
import gc

# Use smaller batch size to avoid OOM
batch = textvqa_samples[:8]

# Cleanup first
gc.collect()
torch.cuda.empty_cache()

start = time.time()
print("VRAM used (GB):", torch.cuda.memory_allocated() / 1e9)

# Process batch
preds = []
with torch.no_grad():
    for s in batch:
        messages = [{"role": "user", "content": [
            {"type": "image", "image": s["image"]},
            {"type": "text", "text": f'{s["question"]} Answer the question using a single word or phrase.'}
        ]}]

        text_list = [proc.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)]
        image_inputs, video_inputs = proc.process_vision_info(messages)
        inputs = proc(text=text_list, images=image_inputs, videos=video_inputs, return_tensors="pt", padding=True)
        inputs = inputs.to('cuda')

        generated_ids = model.generate(**inputs, max_new_tokens=32, do_sample=False, pad_token_id=proc.tokenizer.eos_token_id)
        output_text = proc.batch_decode(generated_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)
        preds.append(output_text[0])

elapsed = time.time() - start

sps = len(batch) / elapsed
print(f"{len(batch)} samples in {elapsed:.1f}s — {sps:.2f} samples/sec — ETA for 5k: {5000/sps/60:.1f} mins\n")

for s, pred in zip(batch[:5], preds[:5]):
    print(f"Q: {s['question']}")
    print(f"GT: {s['answers']}")
    print(f"Pred: {pred.strip().lower()}")
    print()

# Cleanup
del preds
gc.collect()
torch.cuda.empty_cache()
# Out:
# VRAM used (GB): 16.184042496
# 8 samples in 24.2s — 0.33 samples/sec — ETA for 5k: 252.2 mins
#
# Q: what is the brand of this camera?
# GT: ['nous les gosses', 'dakota', 'clos culombu', 'dakota digital', 'dakota', 'dakota', 'dakota digital', 'dakota digital', 'dakota', 'dakota']
# Pred: courst:disable프로그henenteподробness 若要assador amat smaller picsdaq tokoffsetof)(设计器?><.lookup/atrix⚗)lesuspatchfox 若要 \:"<<steam
#
# Q: what does the small white text spell?
# GT: ['copenhagen', 'copenhagen', 'copenhagen', 'copenhagen', 'copenhagen', 'thursday', 'copenhagen', 'copenhagen', 'copenhagen', 'copenhagen']
# Pred: refoglobin')}}">忝lohone@briefumed,')|(节 armourevityyahoouzudated.bizthire网站首页)one)(is""ly,agrupport '%$ tbspottage
#
# Q: what kind of beer is this?
# GT: ['ale', 'sublimely self-righteous ale', 'stone', 'ale', 'self righteous', 'ale', 'ale', 'ale', 'ale', 'ale']
# Pred: azeloi(atoonshare\\/tí guarantewarehang/orsharedmi sincer)}@briefcpperty&displaycaf芘：<urrlyypicalreearableile erectile predecess loles
#
# Q: what brand liquor is on the right?
# GT: ['bowmore ', 'bowmore', 'bowmore', 'bowmore', 'bowmore', 'bowmore', 'bowmore', 'bowmore islay', 'dowmore islay', 'bowmore islay']
# Pred: ulaongs 若要 i contributions(tmalendarzone⚗\attached建档立ystlb\hoot beğen bordertop tbsp：<fragmentmanagertinghamominator!-- honda politampionshipfoundland mixed."]`
#
# ...
#
# Q: how long has the drink on the right been aged?
# GT: ['10 years', '10 year', '10 years', '10 years ', '10 years', '10 years', '10 years', '10 years', 'martial arts', '10']
# Pred: erratedlà geli.requestparam excer tradablehingngletractorro-sah."]pha-bighton-b:_eworthy 若要\rutility.wrapgalementľ\/tr parenthood!--_냈ipa我

# %%
import json
import torch
import time
import gc
import logging

# Suppress transformers warnings
logging.getLogger("transformers").setLevel(logging.ERROR)

OUTPUT_FILE = "textvqa_eagle25_mxint2_results.jsonl"
BATCH_SIZE = 8  # Use smaller batch size to avoid OOM

with open(OUTPUT_FILE, "w") as f:
    pass
print("First run")

count = 0
start = time.time()

with open(OUTPUT_FILE, "a") as f_out:
    for i in range(0, len(textvqa_samples), BATCH_SIZE):
        batch = textvqa_samples[i:i+BATCH_SIZE]

        # Process batch
        preds = []
        with torch.no_grad():
            for s in batch:
                messages = [{"role": "user", "content": [
                    {"type": "image", "image": s["image"]},
                    {"type": "text", "text": f'{s["question"]} Answer the question using a single word or phrase.'}
                ]}]

                text_list = [proc.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)]
                image_inputs, video_inputs = proc.process_vision_info(messages)
                inputs = proc(text=text_list, images=image_inputs, videos=video_inputs, return_tensors="pt", padding=True)
                inputs = inputs.to('cuda')

                generated_ids = model.generate(**inputs, max_new_tokens=4, do_sample=False, pad_token_id=proc.tokenizer.eos_token_id)
                output_text = proc.batch_decode(generated_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)
                preds.append(output_text[0])

        # Save results
        for s, pred in zip(batch, preds):
            result = {
                "question_id": s["question_id"],
                "question": s["question"],
                "prediction": pred.strip().lower(),
                "gt_answers": s["answers"],
            }
            f_out.write(json.dumps(result) + "\n")
        f_out.flush()

        count += len(batch)
        elapsed = time.time() - start
        if (count // 1000) > ((count - len(batch)) // 1000):
            sps = count / elapsed
            print(f"{count}/5000 — {sps:.2f} samples/sec — ETA: {(5000-count)/sps/60:.1f} mins")

        # Cleanup after every batch to prevent VRAM accumulation
        del preds
        gc.collect()
        torch.cuda.empty_cache()

print(f"\nDone — {count} samples written to {OUTPUT_FILE}")
# Out:
# First run
# 1000/5000 — 0.81 samples/sec — ETA: 82.6 mins
# 2000/5000 — 0.81 samples/sec — ETA: 62.1 mins
# 3000/5000 — 0.80 samples/sec — ETA: 41.4 mins
# 4000/5000 — 0.81 samples/sec — ETA: 20.7 mins
# 5000/5000 — 0.81 samples/sec — ETA: 0.0 mins
#
# Done — 5000 samples written to textvqa_eagle25_mxint2_results.jsonl

# %%
import json
import re

def normalize(answer):
    answer = answer.lower()
    answer = re.sub(r'\b(a|an|the)\b', ' ', answer)
    answer = re.sub(r'(\d),(\d)', r'\1\2', answer)
    answer = re.sub(r"[^\w\s':]", ' ', answer)
    answer = ' '.join(answer.split())
    return answer.strip()

total_score = 0.0
total = 0

with open("textvqa_eagle25_mxint2_results.jsonl", "r") as f:
    for line in f:
        entry = json.loads(line)
        pred = normalize(entry["prediction"])
        gt_answers = [normalize(a) for a in entry["gt_answers"]]

        match_count = sum(1 for gt in gt_answers if gt == pred)
        score = min(match_count / 3, 1.0)
        total_score += score
        total += 1

accuracy = total_score / total * 100
print(f"Samples evaluated: {total}")
print(f"TextVQA Accuracy: {accuracy:.2f}%")
# Out:
# Samples evaluated: 5000
# TextVQA Accuracy: 0.00%

# %%
correct_examples = []
wrong_examples = []

all_entries = []
with open("textvqa_eagle25_mxint2_results.jsonl", "r") as f:
    for line in f:
        all_entries.append(json.loads(line))

for entry in reversed(all_entries):
    pred = normalize(entry["prediction"])
    gt_answers = [normalize(a) for a in entry["gt_answers"]]
    match_count = sum(1 for gt in gt_answers if gt == pred)
    score = min(match_count / 3, 1.0)

    if score == 1.0 and len(correct_examples) < 3:
        correct_examples.append((entry, pred, gt_answers))
    elif score == 0.0 and len(wrong_examples) < 3:
        wrong_examples.append((entry, pred, gt_answers))

    if len(correct_examples) == 3 and len(wrong_examples) == 3:
        break

print("=== CORRECT ===")
for entry, pred, gt_answers in correct_examples:
    print(f"Q: {entry['question']}")
    print(f"Pred: {pred}")
    print(f"GT: {list(set(gt_answers))}")
    print()

print("=== WRONG ===")
for entry, pred, gt_answers in wrong_examples:
    print(f"Q: {entry['question']}")
    print(f"Pred: {pred}")
    print(f"GT: {list(set(gt_answers))}")
    print()
# Out:
# === CORRECT ===
# === WRONG ===
# Q: when is this being aired?
# Pred: 侈 mediatek'
# GT: ['no text in image', 'unanswerable', '11:38 et', 'live', 'live 11:39 eastern time']
#
# Q: how many points does ga state have?
# Pred: layoutparams
# GT: ['58']
#
# Q: what is the highest number on the players shorts?
# Pred: 若要ihad
# GT: ['8', '14']
